# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from helpers import *

# %%
# loading the data
path = '/Users/sarrachaabane/Desktop/MA3/ML/ml-project-1-mmlt/projects/project1/data/dataset_to_release'
x_train, x_test, y_train, train_ids, test_ids = load_csv_data(path)
print("Training data loaded: ", x_train.shape, y_train.shape)
print("Test data loaded: ", x_test.shape)
# Out:
# Training data loaded:  (328135, 321) (328135,)
# Test data loaded:  (109379, 321)
